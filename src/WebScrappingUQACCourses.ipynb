# %% [markdown]
# <a href="https://colab.research.google.com/github/Giraud-Pierre/DeepLearning_FineTuneLLama2Project/blob/main/src/WebScrappingUQACCourses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How to use this notebook :**
#
# This notebook intends to gather data on UQAC programs and classes by using webscraping techniques on the UQAC website.
#
# Here are the steps to follow to use this notebook:
#
# - Run the setup which will install and import all required libraries
# - Run Web scrapping which will define and run a proper web scrapping technique for target pages we selected ("https://cours.uqac.ca/premier-cycle" and "https://cours.uqac.ca/cycles-superieurs")
# - You can then
#   - either save the results in a google sheet after authentifying on your google account (do not forget to delete them after usage to save space on your google drive)
#   - or save the variables in a pickle and download using the colab API to be able to reload them in a different colab session

# %% [markdown]
# #**Setup**

# %% [markdown]
# ##Install All the Required Packages

# %%
# !pip install selenium
# !apt-get update
# !apt-get instal chromium-driver
# !pip install gspread
# !pip install --upgrade google-auth
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.10/dist-packages (4.20.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.25.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.2.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.11.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.7)
# Requirement already satisfied: outcome in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.10/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# E: Invalid operation instal
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (3.4.2)
# Requirement already satisfied: requests>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.31.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.10/dist-packages (from gspread) (2.29.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->gspread) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->gspread) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->gspread) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.2.1->gspread) (2024.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth->gspread) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth->gspread) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth->gspread) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth->gspread) (0.6.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.10/dist-packages (2.29.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.0)

# %% [markdown]
# ##Import All the Required Libraries

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import numpy as np
from google.auth import default
from google.colab import auth
from google.auth import default
import gspread

# %% [markdown]
# #**Web scrapping**

# %%
def web_driver():
    options = webdriver.ChromeOptions()
    options.add_argument("--verbose")
    options.add_argument('--no-sandbox')
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument("--window-size=1920, 1200")
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome(options=options)
    return driver

# %%
def GetCourseContent(courseURL):
  # Get the content from a course URL
  driver.get(courseURL)
  return driver.find_elements(By.XPATH, '//div[@id="texte"]')[0].text

def GetAllCoursesURLFromProgram(programContainer):
  # Get all the courses URL available from a progam
  coursesContainer = programContainer.find_elements(By.XPATH, './/table/tbody/tr/td/a')
  coursesURL = []
  for course in coursesContainer:
    coursesURL.append(course.get_attribute('href'))
  return coursesURL

def GetInfoFromProgram(programURL):
  # Get the infos on a program URL, as well as all the courses
  # available to the program and their contents
  driver.get(programURL)

  try:
    testContainer = driver.find_element(By.XPATH,'//h1')
    #print(testContainer.text)
    if "Décanat des études" in testContainer.text:
      return None,None,None,None
  except:
    pass

  programContainer = driver.find_elements(By.XPATH, '//div[@id="texte"]')[0]
  programContent = programContainer.text

  try:
    title = programContainer.find_element(By.XPATH,'.//h1').text
    noProg = programContainer.find_element(By.XPATH,'.//span[@class="noprog"]').text

    coursesURL = GetAllCoursesURLFromProgram(programContainer)

    coursesContent = []

    for course in coursesURL:
      coursesContent.append(GetCourseContent(course))
  except:
    return None,None,None,None

  return title, noProg, programContent, coursesContent


def getProgramsURLFromProgamListPage(programListPageURL):
  # Get all the programs URL from a program page
  # ie: "https://cours.uqac.ca/premier-cycle"
  driver.get(programListPageURL)

  allProgramsContainer = driver.find_elements(By.XPATH, '//div[@id="texte"]/div[@id="liste_prog"]/table/tbody/tr/td')
  allProgramsURL = []

  for container in allProgramsContainer:
    program = container.find_element(By.XPATH,'.//a').get_attribute('href')
    if('cours-offerts' not in program):
      allProgramsURL.append(program)

  return allProgramsURL

def GetAllInfosOnAllPrograms(URL):
  # Get all programs from a programs page as well as the corresponding courses infos
  # ie : "https://cours.uqac.ca/premier-cycle"

  programsURL = getProgramsURLFromProgamListPage(URL)

  #print(programsURL)

  programsContent=[]

  index = 0
  #limit = index + 4

  print("Progress : 0 / " + str(len(programsURL)) + " programs")


  for program in programsURL:
    title, noProg, programContent, coursesContent = GetInfoFromProgram(program)
    index +=1
    if title != None:
      print(str(index) + " / " + str(len(programsURL)) + " programs ==> ")
      print(title + " : " + program)
      programsContent.append([title, noProg, programContent, coursesContent])

  return programsContent

# %%
driver = web_driver()
premierCycleURL = "https://cours.uqac.ca/premier-cycle"

premierCyclePrograms = GetAllInfosOnAllPrograms(premierCycleURL)
# Out:
# Progress : 0 / 237 programs
# 3 / 237 programs ==>
# Certificat en français langue seconde ou étrangère : culture, études et travail : http://programmes.uqac.ca/4447
# 4 / 237 programs ==>
# Programme court d'apprentissage du français parlé et écrit pour non-francophones : http://programmes.uqac.ca/9983
# 5 / 237 programs ==>
# Baccalauréat en éducation préscolaire et en enseignement primaire : http://programmes.uqac.ca/7992
# 6 / 237 programs ==>
# Certificat de perfectionnement en transmission d'une langue autochtone : http://programmes.uqac.ca/4661
# 7 / 237 programs ==>
# Certificat en études pluridisciplinaires : http://programmes.uqac.ca/4385
# 8 / 237 programs ==>
# Certificat en formation d'aides-enseignants en milieu autochtone : http://programmes.uqac.ca/4659
# 9 / 237 programs ==>
# Certificat en formation de suppléants en milieu scolaire autochtone : http://programmes.uqac.ca/4660
# 10 / 237 programs ==>
# Certificat en formation de suppléants en milieu scolaire autochtone : http://programmes.uqac.ca/4670
# 11 / 237 programs ==>
# Certificat en intervention et en prévention des dépendances chez les jeunes des Premières Nations : http://programmes.uqac.ca/4025
# 12 / 237 programs ==>
# Certificat en technolinguistique autochtone : http://programmes.uqac.ca/4144
# 13 / 237 programs ==>
# Programme court de premier cycle de formation de passeurs culturels des arts des Premières Nations (UITAMU) : http://programmes.uqac.ca/0707
# 14 / 237 programs ==>
# Programme court de premier cycle d'intervention en apprentissage d'une langue autochtone : http://programmes.uqac.ca/0544
# 15 / 237 programs ==>
# Programme court de premier cycle en amélioration de la transmission d'une langue autochtone : http://programmes.uqac.ca/9040
# 16 / 237 programs ==>
# Programme court de premier cycle en archéologie pour les Premières Nations : http://programmes.uqac.ca/0907
# 17 / 237 programs ==>
# Programme court de premier cycle en développement du langage chez les enfants des Premières Nations : http://programmes.uqac.ca/0576
# 18 / 237 programs ==>
# Programme court de premier cycle en développement économique en contexte autochtone : http://programmes.uqac.ca/9046
# 19 / 237 programs ==>
# Programme court de premier cycle en éducation préscolaire en contexte autochtone : http://programmes.uqac.ca/0929
# 20 / 237 programs ==>
# Programme court de premier cycle en enseignement en milieu autochtone : http://programmes.uqac.ca/9045
# 21 / 237 programs ==>
# Programme court de premier cycle en français écrit langue seconde pour les Premières Nations : http://programmes.uqac.ca/0676
# 22 / 237 programs ==>
# Programme court de premier cycle en histoire et culture des Premières Nations du nord-est de l'Amérique du Nord : http://programmes.uqac.ca/0464
# 23 / 237 programs ==>
# Programme court de premier cycle en intervention jeunesse autochtone : http://programmes.uqac.ca/0007
# 24 / 237 programs ==>
# Programme court de premier cycle en intervention plein air pour les Premières Nations : http://programmes.uqac.ca/0864
# 25 / 237 programs ==>
# Programme court de premier cycle en prévention des dépendances chez les jeunes des Premières Nations : http://programmes.uqac.ca/0442
# 26 / 237 programs ==>
# Programme court de premier cycle en production audiovisuelle des Premières Nations : http://programmes.uqac.ca/0443
# 27 / 237 programs ==>
# Programme court de premier cycle en relation d'aide : http://programmes.uqac.ca/0139
# 28 / 237 programs ==>
# Baccalauréat en psychologie : http://programmes.uqac.ca/7092
# 29 / 237 programs ==>
# Certificat ou mineure(8350) en psychologie : http://programmes.uqac.ca/4350
# 30 / 237 programs ==>
# Certificat ou mineure(8565) en psychologie du travail et des organisations : http://programmes.uqac.ca/4565
# 33 / 237 programs ==>
# Baccalauréat en éducation préscolaire et en enseignement primaire : http://programmes.uqac.ca/7991
# 35 / 237 programs ==>
# Programme court de premier cycle en éducation au préscolaire et en enseignement au primaire pour étudiants en séjour d'études : http://programmes.uqac.ca/0512
# 36 / 237 programs ==>
# Baccalauréat en enseignement professionnel : http://programmes.uqac.ca/6633
# 37 / 237 programs ==>
# Baccalauréat en enseignement professionnel : http://programmes.uqac.ca/7246
# 38 / 237 programs ==>
# Baccalauréat en enseignement secondaire - profil français : http://programmes.uqac.ca/7651
# 39 / 237 programs ==>
# Baccalauréat en enseignement secondaire - profil mathématique : http://programmes.uqac.ca/7654
# 40 / 237 programs ==>
# Baccalauréat en enseignement secondaire - profil science et technologie : http://programmes.uqac.ca/7653
# 41 / 237 programs ==>
# Baccalauréat en enseignement secondaire - profil univers social : http://programmes.uqac.ca/7665
# 42 / 237 programs ==>
# Certificat en accompagnement à l'enseignement secondaire : http://programmes.uqac.ca/4750
# 43 / 237 programs ==>
# Programme court de premier cycle en enseignement secondaire pour étudiants en séjour d'études : http://programmes.uqac.ca/0609
# 44 / 237 programs ==>
# Baccalauréat en sciences comptables : http://programmes.uqac.ca/7766
# 45 / 237 programs ==>
# Certificat ou mineure(8138) en sciences comptables : http://programmes.uqac.ca/4138
# 47 / 237 programs ==>
# Année préparatoire en sciences économiques et administratives : http://programmes.uqac.ca/5717
# 48 / 237 programs ==>
# Baccalauréat en administration : http://programmes.uqac.ca/7764
# 49 / 237 programs ==>
# Baccalauréat en administration (Gestion des ressources humaines - Sept-Îles Automne 2022) : http://programmes.uqac.ca/6629
# 50 / 237 programs ==>
# Certificat ou mineure(8132) en administration : http://programmes.uqac.ca/4122
# 51 / 237 programs ==>
# Certificat en coaching : http://programmes.uqac.ca/4679
# 52 / 237 programs ==>
# Certificat en gestion de l'hôtellerie et de la restauration des terroirs : http://programmes.uqac.ca/4079
# 53 / 237 programs ==>
# Certificat ou mineure(8283) en gestion des ressources humaines : http://programmes.uqac.ca/4209
# 54 / 237 programs ==>
# Certificat en gestion du transport aérien : http://programmes.uqac.ca/4808
# 55 / 237 programs ==>
# Certificat ou mineure(8206) en marketing : http://programmes.uqac.ca/4206
# 56 / 237 programs ==>
# Certificat en planification financière (général) : http://programmes.uqac.ca/4731
# 57 / 237 programs ==>
# Certificat en planification financière (Mouvement Desjardins) : http://programmes.uqac.ca/4751
# 58 / 237 programs ==>
# Certificat en santé et sécurité au travail : http://programmes.uqac.ca/4253
# 62 / 237 programs ==>
# Programme court de premier cycle de gestion en contexte de sécurité civile : http://programmes.uqac.ca/0729
# 63 / 237 programs ==>
# Programme court de premier cycle en administration pour étudiants en séjour d'études : http://programmes.uqac.ca/0704
# 64 / 237 programs ==>
# Programme court de premier cycle en entrepreneuriat : http://programmes.uqac.ca/0170
# 65 / 237 programs ==>
# Programme court de premier cycle en gestion de projet appliquée en entreprise : http://programmes.uqac.ca/9068
# 66 / 237 programs ==>
# Programme court de premier cycle en gestion du transport aérien : http://programmes.uqac.ca/0008
# 67 / 237 programs ==>
# Programme court de premier cycle en gestion stratégique du transport aérien : http://programmes.uqac.ca/0808
# 68 / 237 programs ==>
# Baccalauréat en biologie : http://programmes.uqac.ca/7705
# 69 / 237 programs ==>
# Baccalauréat en chimie des produits naturels : http://programmes.uqac.ca/7426
# 70 / 237 programs ==>
# Certificat ou mineure(8139) en sciences de l'environnement : http://programmes.uqac.ca/4139
# 72 / 237 programs ==>
# Programme court de premier cycle en biologie pour étudiants en séjour d'études : http://programmes.uqac.ca/0775
# 73 / 237 programs ==>
# Programme court de premier cycle en chimie des produits naturels pour étudiants en séjour d'études : http://programmes.uqac.ca/0821
# 74 / 237 programs ==>
# Baccalauréat en sciences infirmières (Cheminement infirmière en exercice - Volet perfectionnement) : http://programmes.uqac.ca/7453
# 75 / 237 programs ==>
# Baccalauréat en sciences infirmières (Formation initiale - Sept-Îles) : http://programmes.uqac.ca/6640
# 76 / 237 programs ==>
# Baccalauréat en sciences infirmières (Cheminement formation initiale) : http://programmes.uqac.ca/7450
# 77 / 237 programs ==>
# Baccalauréat en sciences infirmières (Cheminement inf. en exercice - Volet intégré- Sept-Îles) : http://programmes.uqac.ca/6641
# 78 / 237 programs ==>
# Baccalauréat en sciences infirmières (Cheminement infirmière en exercice - Volet intégré) : http://programmes.uqac.ca/7452
# 79 / 237 programs ==>
# Certificat d'optimisation en pratique infirmière : http://programmes.uqac.ca/4082
# 80 / 237 programs ==>
# Certificat d'optimisation en pratique infirmière (Sept-Îles) : http://programmes.uqac.ca/4683
# 81 / 237 programs ==>
# Programme court de premier cycle en sciences infirmières pour étudiants en séjour d'études : http://programmes.uqac.ca/9451
# 82 / 237 programs ==>
# Année préparatoire en mathématique et informatique : http://programmes.uqac.ca/5719
# 83 / 237 programs ==>
# Baccalauréat avec majeure en conception de jeux vidéo : http://programmes.uqac.ca/6908
# 84 / 237 programs ==>
# Baccalauréat avec majeure en mathématique : http://programmes.uqac.ca/6801
# 85 / 237 programs ==>
# Baccalauréat en développement de jeux vidéo : http://programmes.uqac.ca/6596
# 86 / 237 programs ==>
# Baccalauréat en informatique : http://programmes.uqac.ca/7833
# 87 / 237 programs ==>
# Baccalauréat en informatique de la science des données et de l'intelligence d'affaires : http://programmes.uqac.ca/6710
# 88 / 237 programs ==>
# Certificat ou mineure(8667) en cybersécurité défensive : http://programmes.uqac.ca/4667
# 89 / 237 programs ==>
# Certificat en design des systèmes de jeux vidéo : http://programmes.uqac.ca/4692
# 90 / 237 programs ==>
# Certificat ou mineure(8567) en développement de jeux vidéo : http://programmes.uqac.ca/4697
# 91 / 237 programs ==>
# Certificat ou mineure(8202) en informatique : http://programmes.uqac.ca/4202
# 92 / 237 programs ==>
# Certificat ou mineure(8128) en informatique appliquée : http://programmes.uqac.ca/4128
# 93 / 237 programs ==>
# Certificat ou mineure(8108) en informatique de gestion : http://programmes.uqac.ca/4108
# 94 / 237 programs ==>
# Certificat ou mineure(8918) en mathématique : http://programmes.uqac.ca/4918
# 95 / 237 programs ==>
# Certificat ou mineure(8810) en science des données et intelligence d'affaires : http://programmes.uqac.ca/4810
# 96 / 237 programs ==>
# Microprogramme de premier cycle en cybersécurité défensive : http://programmes.uqac.ca/9130
# 97 / 237 programs ==>
# Microprogramme de premier cycle en design des systèmes de jeux vidéo : http://programmes.uqac.ca/9134
# 98 / 237 programs ==>
# Microprogramme de premier cycle en développement de jeux vidéo : http://programmes.uqac.ca/9132
# 99 / 237 programs ==>
# Microprogramme de premier cycle en programmation informatique : http://programmes.uqac.ca/9128
# 100 / 237 programs ==>
# Microprogramme de premier cycle en science des données et intelligence d'affaires : http://programmes.uqac.ca/9126
# 108 / 237 programs ==>
# Programme court de premier cycle en cybersécurité défensive : http://programmes.uqac.ca/9131
# 109 / 237 programs ==>
# Programme court de premier cycle en design des systèmes de jeux vidéo : http://programmes.uqac.ca/9135
# 110 / 237 programs ==>
# Programme court de premier cycle en développement de jeux vidéo : http://programmes.uqac.ca/9133
# 111 / 237 programs ==>
# Programme court de premier cycle en informatique pour étudiants en séjour d'études : http://programmes.uqac.ca/0711
# 112 / 237 programs ==>
# Programme court de premier cycle en programmation informatique : http://programmes.uqac.ca/9129
# 113 / 237 programs ==>
# Programme court de premier cycle en science des données et intelligence d'affaires : http://programmes.uqac.ca/9127
# 114 / 237 programs ==>
# Année préparatoire en génie : http://programmes.uqac.ca/5718
# 115 / 237 programs ==>
# Baccalauréat en génie civil : http://programmes.uqac.ca/7480
# 116 / 237 programs ==>
# Baccalauréat en génie électrique : http://programmes.uqac.ca/7944
# 117 / 237 programs ==>
# Baccalauréat en génie informatique : http://programmes.uqac.ca/7943
# 118 / 237 programs ==>
# Baccalauréat en génie mécanique : http://programmes.uqac.ca/7947
# 119 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie I : http://programmes.uqac.ca/0940
# 120 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie II : http://programmes.uqac.ca/0941
# 121 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie III : http://programmes.uqac.ca/0942
# 122 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie IV : http://programmes.uqac.ca/0943
# 123 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie V : http://programmes.uqac.ca/0944
# 124 / 237 programs ==>
# Programme court de premier cycle en génie pour étudiants en séjour d'études : http://programmes.uqac.ca/0713
# 132 / 237 programs ==>
# Baccalauréat en enseignement de l'éducation physique et à la santé : http://programmes.uqac.ca/7208
# 133 / 237 programs ==>
# Certificat ou mineure(8207) en sciences de l'activité physique : http://programmes.uqac.ca/4107
# 135 / 237 programs ==>
# Baccalauréat en enseignement en adaptation scolaire et sociale : http://programmes.uqac.ca/7080
# 136 / 237 programs ==>
# Certificat d'interv. en contexte édu. auprès des personnes ayant un trouble du spectre de l'autisme ou une déficience intellec. : http://programmes.uqac.ca/4448
# 137 / 237 programs ==>
# Certificat d'intervention en contexte éducatif auprès de la personne autiste ou ayant une déficience intellectuelle : http://programmes.uqac.ca/4764
# 138 / 237 programs ==>
# Microprogramme d'introduction à l'intervention contexte éducatif auprès de la pers. autiste ou ayant une déficience intellectuelle : http://programmes.uqac.ca/9165
# 139 / 237 programs ==>
# Prog. court de premier cycle en intervention en contexte éducatif auprès des personnes ayant des troubles du spectre de l'autisme : http://programmes.uqac.ca/0665
# 140 / 237 programs ==>
# Programme court de premier cycle en adaptation scolaire et sociale pour enseignants en exercice : http://programmes.uqac.ca/0695
# 141 / 237 programs ==>
# Programme court d'intervention en contexte éducatif auprès de la personne autiste ou ayant une déficience intellectuelle : http://programmes.uqac.ca/9166
# 142 / 237 programs ==>
# Programme court sur les modèles et approches d'intervention en contexte éducatif auprès des personnes présentant un TSA ou une DI : http://programmes.uqac.ca/0859
# 143 / 237 programs ==>
# Programme court sur les modèles/approches d'interv. contexte éducatif auprès de la personne autiste ou ayant une déficience intel. : http://programmes.uqac.ca/9167
# 144 / 237 programs ==>
# Baccalauréat en animation 3D et en design numérique : http://programmes.uqac.ca/7179
# 145 / 237 programs ==>
# Baccalauréat en création 3D pour le cinéma : http://programmes.uqac.ca/6666
# 146 / 237 programs ==>
# Baccalauréat en création 3D pour le jeu vidéo (Arts techniques) : http://programmes.uqac.ca/7376
# 147 / 237 programs ==>
# Baccalauréat en création 3D pour le jeu vidéo (Jeu vidéo) : http://programmes.uqac.ca/6667
# 148 / 237 programs ==>
# Certificat en animation 3D et en design numérique : http://programmes.uqac.ca/4067
# 149 / 237 programs ==>
# Certificat en arts techniques pour le jeu vidéo : http://programmes.uqac.ca/4676
# 150 / 237 programs ==>
# Programme court de premier cycle en animation 3D et en design numérique pour étudiants en séjour d'études : http://programmes.uqac.ca/9067
# 151 / 237 programs ==>
# Baccalauréat en enseignement des arts : http://programmes.uqac.ca/7209
# 152 / 237 programs ==>
# Baccalauréat interdisciplinaire en arts : http://programmes.uqac.ca/7886
# 153 / 237 programs ==>
# Certificat de perfectionnement en formation artistique : http://programmes.uqac.ca/4437
# 154 / 237 programs ==>
# Certificat ou mineure(8068) en arts numériques : http://programmes.uqac.ca/4068
# 155 / 237 programs ==>
# Certificat ou mineure(8769) en arts visuels : http://programmes.uqac.ca/4769
# 156 / 237 programs ==>
# Certificat ou mineure(8071) en cinéma et en vidéo : http://programmes.uqac.ca/4371
# 157 / 237 programs ==>
# Certificat ou mineure(8073) en théâtre : http://programmes.uqac.ca/4173
# 162 / 237 programs ==>
# Programme court de premier cycle en arts pour étudiants en séjour d'études : http://programmes.uqac.ca/0735
# 164 / 237 programs ==>
# Baccalauréat avec majeure en études littéraires françaises : http://programmes.uqac.ca/6110
# 165 / 237 programs ==>
# Baccalauréat en études littéraires françaises : http://programmes.uqac.ca/7792
# 166 / 237 programs ==>
# Certificat ou mineure(8803) en création littéraire : http://programmes.uqac.ca/4803
# 167 / 237 programs ==>
# Certificat ou mineure(8627) en scénarisation : http://programmes.uqac.ca/5327
# 170 / 237 programs ==>
# Programme court de premier cycle en études littéraires pour étudiants en séjour d'études : http://programmes.uqac.ca/9009
# 171 / 237 programs ==>
# Programme court de premier cycle en littérature québécoise et création littéraire pour étudiants en séjour d'études : http://programmes.uqac.ca/9008
# 173 / 237 programs ==>
# Programme court de premier cycle en intervention rituelle et symbolique : http://programmes.uqac.ca/0417
# 174 / 237 programs ==>
# Baccalauréat en intervention plein air : http://programmes.uqac.ca/7309
# 175 / 237 programs ==>
# Programme court de premier cycle en intervention plein air : http://programmes.uqac.ca/9052
# 176 / 237 programs ==>
# Programme court de premier cycle en intervention plein air : http://programmes.uqac.ca/9143
# 178 / 237 programs ==>
# Baccalauréat en kinésiologie : http://programmes.uqac.ca/7437
# 179 / 237 programs ==>
# Certificat ou mineure(8737) en kinésiologie : http://programmes.uqac.ca/4737
# 182 / 237 programs ==>
# Baccalauréat en sciences (réadaptation) : http://programmes.uqac.ca/1520
# 183 / 237 programs ==>
# Baccalauréat en sciences (réadaptation) : http://programmes.uqac.ca/6598
# 185 / 237 programs ==>
# Baccalauréat en génie géologique : http://programmes.uqac.ca/7942
# 186 / 237 programs ==>
# Baccalauréat en géologie : http://programmes.uqac.ca/7728
# 187 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie et en géologie I : http://programmes.uqac.ca/0945
# 188 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie et en géologie II : http://programmes.uqac.ca/0946
# 189 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie et en géologie III : http://programmes.uqac.ca/0947
# 190 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie et en géologie IV : http://programmes.uqac.ca/0948
# 191 / 237 programs ==>
# Microprogramme de stage de premier cycle en génie et en géologie V : http://programmes.uqac.ca/0949
# 192 / 237 programs ==>
# Programme court de premier cycle en sciences de la Terre pour étudiants en séjour d'études : http://programmes.uqac.ca/0714
# 193 / 237 programs ==>
# Baccalauréat en géographie et en aménagement durable : http://programmes.uqac.ca/7688
# 194 / 237 programs ==>
# Baccalauréat en histoire : http://programmes.uqac.ca/7758
# 195 / 237 programs ==>
# Baccalauréat en science politique : http://programmes.uqac.ca/7620
# 196 / 237 programs ==>
# Baccalauréat en sociologie appliquée : http://programmes.uqac.ca/7404
# 197 / 237 programs ==>
# Certificat ou mineure(8213) en archéologie : http://programmes.uqac.ca/4213
# 198 / 237 programs ==>
# Certificat ou mineure(8410) en coopération internationale : http://programmes.uqac.ca/4910
# 199 / 237 programs ==>
# Certificat ou mineure(8115) en géographie : http://programmes.uqac.ca/4915
# 200 / 237 programs ==>
# Certificat ou mineure(8347) en gestion des documents et des archives : http://programmes.uqac.ca/4347
# 201 / 237 programs ==>
# Certificat ou mineure(8116) en histoire : http://programmes.uqac.ca/4116
# 202 / 237 programs ==>
# Certificat ou mineure(8912) en science politique : http://programmes.uqac.ca/4912
# 203 / 237 programs ==>
# Certificat ou mineure(8562) en sociologie : http://programmes.uqac.ca/4562
# 209 / 237 programs ==>
# Programme court de premier cycle en sciences humaines pour étudiants en séjour d'études : http://programmes.uqac.ca/0724
# 213 / 237 programs ==>
# Baccalauréat en communication interculturelle et médiatique : http://programmes.uqac.ca/6515
# 214 / 237 programs ==>
# Baccalauréat en enseignement de l'anglais langue seconde : http://programmes.uqac.ca/7104
# 215 / 237 programs ==>
# Baccalauréat en enseignement des langues secondes : http://programmes.uqac.ca/7207
# 216 / 237 programs ==>
# Baccalauréat en langues modernes : http://programmes.uqac.ca/7896
# 217 / 237 programs ==>
# Baccalauréat en linguistique et langue française : http://programmes.uqac.ca/7079
# 218 / 237 programs ==>
# Baccalauréat en sciences du langage : http://programmes.uqac.ca/6712
# 219 / 237 programs ==>
# Certificat ou mineure(8149) en anglais langue seconde : http://programmes.uqac.ca/4149
# 220 / 237 programs ==>
# Certificat en communication : http://programmes.uqac.ca/4214
# 221 / 237 programs ==>
# Certificat ou mineure(8127) en espagnol : http://programmes.uqac.ca/4127
# 222 / 237 programs ==>
# Certificat ou mineure(8016) en rédaction-communications : http://programmes.uqac.ca/4016
# 226 / 237 programs ==>
# Programme court de premier cycle en anglais langue seconde : http://programmes.uqac.ca/0287
# 227 / 237 programs ==>
# Programme court de premier cycle en communication interculturelle et médiatique pour étudiants en séjour d'études : http://programmes.uqac.ca/0988
# 228 / 237 programs ==>
# Programme court de premier cycle en langue espagnole : http://programmes.uqac.ca/0181
# 229 / 237 programs ==>
# Programme court de premier cycle en langues modernes pour étudiants en séjour d'études : http://programmes.uqac.ca/0805
# 230 / 237 programs ==>
# Baccalauréat en travail social : http://programmes.uqac.ca/7798
# 231 / 237 programs ==>
# Baccalauréat en travail social (Sept-îles-Automne 2022) : http://programmes.uqac.ca/6619
# 232 / 237 programs ==>
# Baccalauréat en travail social (Trois-Rivières - Aut 2024) : http://programmes.uqac.ca/6618
# 233 / 237 programs ==>
# Certificat en intervention communautaire : http://programmes.uqac.ca/4394
# 234 / 237 programs ==>
# Certificat ou mineure(8366) en intervention jeunesse : http://programmes.uqac.ca/4766
# 235 / 237 programs ==>
# Certificat en toxicomanies et autres dépendances : http://programmes.uqac.ca/4439

# %%
driver = web_driver()
premierCycleURL = "https://cours.uqac.ca/cycles-superieurs"

CyclesSuperieurs = GetAllInfosOnAllPrograms(premierCycleURL)
# Out:
# Doctorat en lettres : http://programmes.uqac.ca/2056
# Doctorat en lettres : http://programmes.uqac.ca/3136
# Maîtrise en art : http://programmes.uqac.ca/3848
# Maîtrise en lettres : http://programmes.uqac.ca/2036
# Maîtrise en lettres : http://programmes.uqac.ca/3073
# Maîtrise en linguistique : http://programmes.uqac.ca/3637
# Programme court de deuxième cycle en pratiques artistiques en théâtre jeunesse : http://programmes.uqac.ca/9032
# Diplôme d'études supérieures spécialisées en gestion publique en contexte autochtone : http://programmes.uqac.ca/1803
# Diplôme d'études supérieures spécialisées multidisciplinaires de recherche en contexte autochtone : http://programmes.uqac.ca/1806
# Microprogramme de deuxième cycle en gestion publique en contexte autochtone : http://programmes.uqac.ca/0884
# Programme court de deuxième cycle en gestion publique en contexte autochtone : http://programmes.uqac.ca/0885
# Diplôme d'études supérieures spécialisées en design de jeu vidéo narratif : http://programmes.uqac.ca/1663
# Maîtrise en art (design numérique) : http://programmes.uqac.ca/1899
# Diplôme d'études supérieures spécialisées en informatique appliquée : http://programmes.uqac.ca/3775
# Doctorat en informatique : http://programmes.uqac.ca/3121
# Doctorat en sciences et technologies de l'information : http://programmes.uqac.ca/3081
# Maîtrise en informatique : http://programmes.uqac.ca/3017
# Maîtrise en informatique (cybersécurité) : http://programmes.uqac.ca/2138
# Maîtrise en informatique (intelligence artificielle) : http://programmes.uqac.ca/2139
# Maîtrise en informatique (jeux vidéo) : http://programmes.uqac.ca/1537
# Maîtrise en informatique (professionnel) : http://programmes.uqac.ca/3037
# Microprogramme de deuxième cycle en développement de jeux vidéo : http://programmes.uqac.ca/0962
# Programme court de deuxième cycle en développement de jeux vidéo : http://programmes.uqac.ca/0963
# Programme court de deuxième cycle en informatique pour étudiants en séjour d'études : http://programmes.uqac.ca/0784
# Doctorat en ingénierie : http://programmes.uqac.ca/3737
# Doctorat en sciences de la Terre et de l'atmosphère : http://programmes.uqac.ca/3141
# Maîtrise en géologie et génie géologique : http://programmes.uqac.ca/1666
# Maîtrise en géologie et génie géologique : http://programmes.uqac.ca/1667
# Maîtrise en géologie et génie géologique - Environnement et hydrogéologie minière : http://programmes.uqac.ca/2106
# Maîtrise en géologie et génie géologique - Exploration minérale : http://programmes.uqac.ca/2105
# Maîtrise en ingénierie : http://programmes.uqac.ca/1709
# Maîtrise en ingénierie : http://programmes.uqac.ca/3708
# Programme court de 2e cycle en développement professionnel en sciences et génie d'exploration minérale : http://programmes.uqac.ca/0738
# Programme court de deuxième cycle en ingénierie pour étudiants en séjour d'études : http://programmes.uqac.ca/0876
# Programme court de deuxième cycle pour l'utilisation du matériau bois dans la construction : http://programmes.uqac.ca/0723
# Diplôme d'études supérieures spécialisées en kinésiologie : http://programmes.uqac.ca/2437
# Diplôme d'études supérieures spécialisées en sciences infirmières : http://programmes.uqac.ca/3599
# Diplôme d'études supérieures spécialisées en sciences infirmières (IPS soins de première ligne) : http://programmes.uqac.ca/2299
# Doctorat en psychologie : http://programmes.uqac.ca/3160
# Doctorat en psychologie (neuropsychologie) : http://programmes.uqac.ca/1747
# Doctorat en psychologie (psychologie clinique) : http://programmes.uqac.ca/1746
# Maîtrise en santé durable : http://programmes.uqac.ca/2094
# Maîtrise en sciences cliniques et biomédicales : http://programmes.uqac.ca/1601
# Maîtrise en sciences cliniques et biomédicales : http://programmes.uqac.ca/1914
# Maîtrise en sciences infirmières : http://programmes.uqac.ca/3576
# Maîtrise en sciences infirmières (IPS soins de première ligne) : http://programmes.uqac.ca/2259
# Maîtrise en sciences infirmières (profil clinique) : http://programmes.uqac.ca/2210
# Maîtrise en sciences infirmières (santé mentale et soins psychiatriques) : http://programmes.uqac.ca/3258
# Maîtrise ès sciences appliquées en physiothérapie : http://programmes.uqac.ca/1821
# Maîtrise ès sciences appliquées en physiothérapie : http://programmes.uqac.ca/1978
# Diplôme d'études supérieures spécialisées en administration scolaire : http://programmes.uqac.ca/3764
# Diplôme d'études supérieures spécialisées en enseignement collégial : http://programmes.uqac.ca/3151
# Diplôme d'études supérieures spécialisées en intervention éducative : http://programmes.uqac.ca/3198
# Doctorat en éducation : http://programmes.uqac.ca/3666
# Maîtrise en éducation : http://programmes.uqac.ca/3414
# Maîtrise en éducation : http://programmes.uqac.ca/3664
# Maîtrise en éducation (orthopédagogie) : http://programmes.uqac.ca/2415
# Programme court de deuxième cycle en développement professionnel par la recherche participative en éducation : http://programmes.uqac.ca/9051
# Diplôme d'études supérieures spécialisées en gestion de projet : http://programmes.uqac.ca/3149
# Diplôme d'études supérieures spécialisées en sciences comptables : http://programmes.uqac.ca/1809
# Doctorat en management de projets : http://programmes.uqac.ca/3077
# Maîtrise en administration des affaires : http://programmes.uqac.ca/3016
# Maîtrise en administration des affaires (Sept-Îles) : http://programmes.uqac.ca/2058
# Maîtrise en gestion de projet : http://programmes.uqac.ca/3153
# Maîtrise en gestion de projet : http://programmes.uqac.ca/3249
# Maîtrise en gestion des organisations : http://programmes.uqac.ca/3754
# Maîtrise en gestion des organisations : http://programmes.uqac.ca/3755
# Maîtrise par cumul (sciences comptables) : http://programmes.uqac.ca/1792
# Programme court de deuxième cycle en gestion de projet : http://programmes.uqac.ca/0749
# Programme court de deuxième cycle en information financière et organisationnelle : http://programmes.uqac.ca/0851
# Programme court de troisième cycle en management de projets : http://programmes.uqac.ca/0777
# Diplôme d'études supérieures spécialisées en cosmétologie : http://programmes.uqac.ca/1505
# Diplôme d'études supérieures spécialisées en éco-conseil : http://programmes.uqac.ca/3598
# Doctorat en biologie : http://programmes.uqac.ca/3805
# Doctorat en sciences de l'environnement : http://programmes.uqac.ca/3583
# Doctorat en sciences de l'environnement : http://programmes.uqac.ca/3669
# Maîtrise en ressources renouvelables : http://programmes.uqac.ca/3018
# Maîtrise par cumul (éco-conseil) : http://programmes.uqac.ca/3550
# Programme court de deuxième cycle en cosmétologie : http://programmes.uqac.ca/9015
# Programme court de deuxième cycle en développement durable appliqué : http://programmes.uqac.ca/0850
# Programme court de deuxième cycle en gestion durable du carbone : http://programmes.uqac.ca/0657
# Programme court de deuxième cycle en transition socio-écologique : http://programmes.uqac.ca/9044
# Diplôme d'études supérieures spécialisées en éthique appliquée : http://programmes.uqac.ca/1924
# Diplôme d'études supérieures spécialisées en intervention nature et aventure : http://programmes.uqac.ca/2042
# Diplôme d'études supérieures spécialisées en intervention par la nature et l'aventure : http://programmes.uqac.ca/1597
# Doctorat en développement régional : http://programmes.uqac.ca/3770
# Doctorat en développement régional et territorial : http://programmes.uqac.ca/2077
# Doctorat en sciences humaines appliquées : http://programmes.uqac.ca/2064
# Maîtrise en études et interventions régionales : http://programmes.uqac.ca/3593
# Maîtrise en études et interventions régionales : http://programmes.uqac.ca/3595
# Maîtrise en histoire : http://programmes.uqac.ca/2221
# Maîtrise en sociétés, autodéterminations et développement : http://programmes.uqac.ca/1602
# Maîtrise en travail social : http://programmes.uqac.ca/3563
# Maîtrise en travail social : http://programmes.uqac.ca/3763
# Programme court de deuxième cycle en éthique clinique : http://programmes.uqac.ca/0920
# Programme court de deuxième cycle en éthique professionnelle et organisationnelle : http://programmes.uqac.ca/0870
# Programme court de deuxième cycle en études régionales : http://programmes.uqac.ca/0184

# %% [markdown]
# #**Saving results in a google sheet**

# %%
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
gs = gc.create('PremierCycles')
sh = gs.sheet1
#sh.append_row(["title","program number","program content","courses content"])

for program in premierCyclePrograms:
  programData = []
  programData.append(program[0])
  programData.append(program[1])
  programData.append(program[2])
  for course in program[3]:
    programData.append(course)
  sh.append_row(programData)

# %%
gs = gc.create('CyclesSupérieurs')
sh = gs.sheet1
sh.append_row(["title","program number","program content","courses content"])

for program in CyclesSuperieurs:
  programData = []
  programData.append(program[0])
  programData.append(program[1])
  programData.append(program[2])
  for course in program[3]:
    programData.append(course)
  sh.append_row(programData)

# %% [markdown]
# #**Saving variables in a pickle**

# %% [markdown]
# Can be used to store and load colab variables for usage in a later session (as here, the web scrapping can take a long time, you can store the variable here to be able to reload them later without having to redo all the web scrapping)

# %%
import pickle

# %%
filePathCyclesSuperieurs = "CyclesSuperieurs.pickle"
filePathPremierCycles = "PremiersCycles.pickle"

# Open the file in binary mode
with open(filePathPremierCycles, 'wb') as file:
    # Serialize and write the variable to the file
    pickle.dump(premierCyclePrograms, file)

# Open the file in binary mode
with open(filePathCyclesSuperieurs, 'wb') as file:
    # Serialize and write the variable to the file
    pickle.dump(CyclesSuperieurs, file)

# %%
# Open the file in binary mode
with open(filePathCyclesSuperieurs, 'rb') as file:
    # Deserialize and retrieve the variable from the file
    loaded_data = pickle.load(file)

# %%
loaded_data
